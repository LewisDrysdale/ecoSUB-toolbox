# %% [markdown]
# # Read and plot data from ecoSUB micro

# %%
import numpy as np
import pandas as pd
import cmocean
import cmocean.cm as cmo
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/ecoSUB C3 GUI/Logs/20210810/300434062118160/20210810_141843_ecosub_state_v2.csv',sep=';')

# %%
df.head()
# Out:
#            Time   Latitude  Longitude     Depth  Forward Speed  RPM   Heading  \
# 0  1.628605e+09  56.477009  -5.433524  0.038594           -0.0    0  223.6875
# 1  1.628605e+09  56.477009  -5.433524  0.051854           -0.0    0  217.9375
# 2  1.628605e+09  56.477009  -5.433524  0.051854           -0.0    0  217.9375
# 3  1.628605e+09  56.477016  -5.433525  0.046082           -0.0    0  231.6875
# 4  1.628605e+09  56.477016  -5.433525  0.046082           -0.0    0  231.6875
#
#      Pitch     Roll  Moving mass position  ...  Temperature  \
# 0 -52.0000   9.1250                    97  ...        33.33
# 1 -53.6250  13.8125                    97  ...        33.33
# 2 -53.6250  13.8125                    97  ...        30.53
# 3 -56.3125  12.0000                    93  ...        30.53
# 4 -56.3125  12.0000                    93  ...        30.53
#
#    Conductivity Status  Conductivity  Sound_Velocity Status  Sound_Velocity  \
# 0                    1         37.55                      0               0
# 1                    1         37.55                      0               0
# 2                    1         37.55                      0               0
# 3                    1         37.55                      0               0
# 4                    1         37.55                      0               0
#
#    Methane Status  Methane  Acoustic Status  Acoustic  Iridium Modem Status
# 0               0        0                0         0                  Idle
# 1               0        0                0         0                  Idle
# 2               0        0                0         0                  Idle
# 3               0        0                0         0                  Idle
# 4               0        0                0         0                  Idle
#
# [5 rows x 43 columns]

# %%
x=df.Longitude
y=df.Latitude
z=df.Depth
cz=df.Temperature

fig = plt.figure()
ax = plt.axes(projection='3d')
sctt = ax.scatter3D(x, y, z,
                    alpha = 0.8,
                    c=cz,
                    cmap='cmo.thermal',
                    marker ='^')
 
plt.title("simple 3D scatter plot")
ax.set_xlabel('X-axis', fontweight ='bold')
ax.set_ylabel('Y-axis', fontweight ='bold')
ax.set_zlabel('Z-axis', fontweight ='bold')
fig.colorbar(sctt, ax = ax, shrink = 0.5, aspect = 5)
 
# show plot
plt.show()
