# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

path='D:/'
fle='20221017_145416_ecosub_state_v2'
fname=os.path.join(path,fle+'.csv')
df=pd.read_csv(fname,sep=';')

# %%
plt.plot(df.Time,df.Depth)
